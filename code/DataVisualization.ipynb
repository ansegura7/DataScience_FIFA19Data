# %% [markdown]
# # Visual and Data Analysis - FIFA 19 Players
# - **Created by Andrés Segura Tinoco**
# - **Created on May 1, 2019**

# %% [markdown]
# # 3. Data Visualization
# ## Loading main libraries and data

# %%
# Load the Pandas libraries
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
# Load visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read FIFA 19 players data only using the current skill values
dataURL = "https://raw.githubusercontent.com/ansegura7/DataScience_FIFA19Data/master/data/fifa19_overall_data.csv"
data = pd.read_csv(dataURL)

# %% [markdown]
# ## Selecting categorical and numeric variables

# %%
# UTIL FUNCTION - Get Dataframe Columns List By Type
def getColumnsByType(data, colType, equals, show):
    colList = []
    for col in data.columns:
        if (equals and str(data[col].dtype) == colType) or (not equals and str(data[col].dtype) != colType):
            colList.append(col)
            if show:
                print(str(data.columns.get_loc(col)) + " - " + col + " - " + str(data[col].dtype))
    return colList;

# %%
# Show object (string or date) type columns
objColList = getColumnsByType(data, "object", True, True)
# Out:
# 2 - Name - object
# 4 - Photo - object
# 5 - Nationality - object
# 6 - Flag - object
# 9 - Club - object
# 10 - Club Logo - object
# 14 - Preferred Foot - object
# 18 - Work Rate - object
# 19 - Body Type - object
# 20 - Real Face - object
# 21 - Position - object
# 23 - Joined - object
# 24 - Loaned_From - object
# 25 - Contract Valid Until - object

# %%
# Show numeric (float or integer) type columns
numColList = getColumnsByType(data, "object", False, True)
# Out:
# 0 - Order - int64
# 1 - ID - int64
# 3 - Age - int64
# 7 - Overall - int64
# 8 - Potential - int64
# 11 - Value € - float64
# 12 - Wage € - float64
# 13 - Special - int64
# 15 - International Reputation - float64
# 16 - Weak Foot - float64
# 17 - Skill Moves - float64
# 22 - Jersey Number - float64
# 26 - HeightMts - float64
# 27 - WeightLbs - float64
# 28 - LS - int64
# 29 - ST - int64
# 30 - RS - int64
# 31 - LW - int64
# 32 - LF - int64
# 33 - CF - int64
# 34 - RF - int64
# 35 - RW - int64
# 36 - LAM - int64
# 37 - CAM - int64
# 38 - RAM - int64
# 39 - LM - int64
# 40 - LCM - int64
# 41 - CM - int64
# 42 - RCM - int64
# 43 - RM - int64
# 44 - LWB - int64
# 45 - LDM - int64
# 46 - CDM - int64
# 47 - RDM - int64
# 48 - RWB - int64
# 49 - LB - int64
# 50 - LCB - int64
# 51 - CB - int64
# 52 - RCB - int64
# 53 - RB - int64
# 54 - Crossing - float64
# 55 - Finishing - float64
# 56 - HeadingAccuracy - float64
# 57 - ShortPassing - float64
# 58 - Volleys - float64
# 59 - Dribbling - float64
# 60 - Curve - float64
# 61 - FKAccuracy - float64
# 62 - LongPassing - float64
# 63 - BallControl - float64
# 64 - Acceleration - float64
# 65 - SprintSpeed - float64
# 66 - Agility - float64
# 67 - Reactions - float64
# 68 - Balance - float64
# 69 - ShotPower - float64
# 70 - Jumping - float64
# 71 - Stamina - float64
# 72 - Strength - float64
# 73 - LongShots - float64
# 74 - Aggression - float64
# 75 - Interceptions - float64
# 76 - Positioning - float64
# 77 - Vision - float64
# 78 - Penalties - float64
# 79 - Composure - float64
# 80 - Marking - float64
# 81 - StandingTackle - float64
# 82 - SlidingTackle - float64
# 83 - GKDiving - float64
# 84 - GKHandling - float64
# 85 - GKKicking - float64
# 86 - GKPositioning - float64
# 87 - GKReflexes - float64
# 88 - Release Clause € - float64

# %%
# Split data into header and skills dataframes
header = pd.DataFrame()
skills = pd.DataFrame()

for col in data.columns:
    if col in objColList:
        header[col] = data[col]
    else:
        skills[col] = data[col]

# Delete original dataset from memory
del data

# %%
# Show first 5 rows of header dataframe
header.head()
# Out:
#                 Name                                           Photo  \
# 0           L. Messi  https://cdn.sofifa.org/players/4/19/158023.png
# 1  Cristiano Ronaldo   https://cdn.sofifa.org/players/4/19/20801.png
# 2          Neymar Jr  https://cdn.sofifa.org/players/4/19/190871.png
# 3             De Gea  https://cdn.sofifa.org/players/4/19/193080.png
# 4       K. De Bruyne  https://cdn.sofifa.org/players/4/19/192985.png
#
#   Nationality                                 Flag                 Club  \
# 0   Argentina  https://cdn.sofifa.org/flags/52.png         FC Barcelona
# 1    Portugal  https://cdn.sofifa.org/flags/38.png             Juventus
# 2      Brazil  https://cdn.sofifa.org/flags/54.png  Paris Saint-Germain
# 3       Spain  https://cdn.sofifa.org/flags/45.png    Manchester United
# 4     Belgium   https://cdn.sofifa.org/flags/7.png      Manchester City
#
#                                       Club Logo Preferred Foot  \
# 0  https://cdn.sofifa.org/teams/2/light/241.png           Left
# 1   https://cdn.sofifa.org/teams/2/light/45.png          Right
# 2   https://cdn.sofifa.org/teams/2/light/73.png          Right
# 3   https://cdn.sofifa.org/teams/2/light/11.png          Right
# 4   https://cdn.sofifa.org/teams/2/light/10.png          Right
#
#         Work Rate   Body Type Real Face Position     Joined Loaned_From  \
# 0  Medium/ Medium       Messi       Yes       RF   1-Jul-04         NaN
# 1       High/ Low  C. Ronaldo       Yes       ST  10-Jul-18         NaN
# 2    High/ Medium      Neymar       Yes       LW   3-Aug-17         NaN
# 3  Medium/ Medium        Lean       Yes       GK   1-Jul-11         NaN
# 4      High/ High      Normal       Yes      RCM  30-Aug-15         NaN
#
#   Contract Valid Until
# 0                 2021
# 1                 2022
# 2                 2022
# 3                 2020
# 4                 2023

# %%
# Show first 5 rows of skills dataframe
skills.head()
# Out:
#    Order      ID  Age  Overall  Potential      Value €    Wage €  Special  \
# 0      0  158023   31       94         94  110500000.0  565000.0     2202
# 1      1   20801   33       94         94   77000000.0  405000.0     2228
# 2      2  190871   26       92         93  118500000.0  290000.0     2143
# 3      3  193080   27       91         93   72000000.0  260000.0     1471
# 4      4  192985   27       91         92  102000000.0  355000.0     2281
#
#    International Reputation  Weak Foot  ...  Composure  Marking  \
# 0                       5.0        4.0  ...       96.0     33.0
# 1                       5.0        4.0  ...       95.0     28.0
# 2                       5.0        5.0  ...       94.0     27.0
# 3                       4.0        3.0  ...       68.0     15.0
# 4                       4.0        5.0  ...       88.0     68.0
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0            28.0           26.0       6.0        11.0       15.0
# 1            31.0           23.0       7.0        11.0       15.0
# 2            24.0           33.0       9.0         9.0       15.0
# 3            21.0           13.0      90.0        85.0       87.0
# 4            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes  Release Clause €
# 0           14.0         8.0       226500000.0
# 1           14.0        11.0       127100000.0
# 2           15.0        11.0       228100000.0
# 3           88.0        94.0       138600000.0
# 4           10.0        13.0       196400000.0
#
# [5 rows x 75 columns]

# %% [markdown]
# ## Data Quality Process

# %%
# Filter/Delete player with an overall below 85
threshold = 85
skills = skills.loc[skills["Overall"] >= threshold]
len(skills)
# Out:
# 110

# %%
# Remove columns that are not relevant for the analysis
nonColumns = ["Order", "ID", "Overall", "Potential", "Value €", "Wage €", "Release Clause €"]
skills = skills.drop(nonColumns, axis=1)
numColList = [e for e in numColList if e not in nonColumns]

# %%
# Columns size validation
len(skills.columns) == len(numColList)
# Out:
# True

# %%
# Replace NaN values with average of columns
skills = skills.fillna(skills.mean())

# %%
# Standardize the Data
nCol = len(skills.columns)
x = skills.loc[:,numColList].values
x = StandardScaler().fit_transform(x)

# Show skills data in temporary dataframe
dfHeader = pd.DataFrame(data = x, columns = numColList).head()
dfHeader
# Out:
#         Age   Special  International Reputation  Weak Foot  Skill Moves  \
# 0  0.776706  0.724004                  2.310325   0.743626     0.831174
# 1  1.361895  0.822752                  2.310325   0.743626     1.693714
# 2 -0.686267  0.499921                  2.310325   2.084591     1.693714
# 3 -0.393673 -2.052339                  0.882596  -0.597339    -1.756444
# 4 -0.393673  1.024046                  0.882596   2.084591     0.831174
#
#    Jersey Number  HeightMts  WeightLbs        LS        ST  ...  Penalties  \
# 0      -0.173639  -1.639945  -0.770754  0.818270  0.818270  ...   0.595888
# 1      -0.548156   0.723295   0.560044  0.938657  0.938657  ...   1.145324
# 2      -0.173639  -0.983490  -1.269804  0.657753  0.657753  ...   0.925549
# 3      -1.297189   1.379750  -0.271705 -2.713095 -2.713095  ...  -1.327137
# 4      -0.548156  -0.327034  -1.048004  0.577495  0.577495  ...   0.815662
#
#    Composure   Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0   2.111447 -1.062921       -1.027494      -0.951904 -0.517153   -0.308874
# 1   1.955673 -1.267257       -0.919025      -1.059078 -0.475901   -0.308874
# 2   1.799899 -1.308124       -1.172118      -0.701830 -0.393397   -0.393602
# 3  -2.250227 -1.798531       -1.280587      -1.416327  2.948037    2.826078
# 4   0.865254  0.367434        0.057193      -0.058784 -0.145883   -0.224145
#
#    GKKicking  GKPositioning  GKReflexes
# 0  -0.119577      -0.178222   -0.423847
# 1  -0.119577      -0.178222   -0.303270
# 2  -0.119577      -0.136510   -0.303270
# 3   3.146120       2.908430    3.032701
# 4  -0.573146      -0.345068   -0.222885
#
# [5 rows x 68 columns]

# %% [markdown]
# ## Correlation Matrix Plot

# %%
corr = dfHeader.corr()

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
fig, ax1 = plt.subplots(figsize = (18, 18))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(20, 220, n = 200)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask = mask, cmap = cmap, vmin = -1, vmax = 1, center = 0,
            square = True, linewidths = .5, cbar_kws = {"shrink": .5})

ax1.set_xticklabels(ax1.get_xticklabels(), rotation = 45, horizontalalignment = 'right');

# Add title
ax1.set_title("Correlation Matrix", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# ## PCA Process

# %%
# Principal Component Analysis
pca = PCA(n_components = 2)
pcaData = pca.fit_transform(x)

# %%
# Create and show principal components DataFrame
pcaDF = pd.DataFrame(data = pcaData, columns = ["PC1", "PC2"])
pcaDF = pd.concat([pcaDF, header[["Name"]]], axis = 1)
pcaDF = pcaDF[pcaDF["PC1"].notnull()]
pcaDF
# Out:
#            PC1       PC2               Name
# 0    -4.593481 -5.478033           L. Messi
# 1    -4.080334 -3.406618  Cristiano Ronaldo
# 2    -4.048185 -5.546171          Neymar Jr
# 3    17.658339 -2.364764             De Gea
# 4    -4.982714 -1.635134       K. De Bruyne
# 5    -3.976332 -4.619820          E. Hazard
# 6    -4.938277 -1.234102          L. Modrić
# 7    -3.226382 -1.905506          L. Suárez
# 8    -2.522402  3.734704       Sergio Ramos
# 9    18.786267 -1.573208           J. Oblak
# 10   -2.881610 -2.218374     R. Lewandowski
# 11   -3.995502 -0.098698           T. Kroos
# 12    0.367889  5.498168           D. Godín
# 13   -3.577537 -2.829777        David Silva
# 14   -3.363312  2.148710           N. Kanté
# 15   -3.174919 -4.402284          P. Dybala
# 16   -2.919689 -1.103968            H. Kane
# 17   -3.975070 -2.464858       A. Griezmann
# 18   18.655676 -1.040415      M. ter Stegen
# 19   18.942730 -1.307173        T. Courtois
# 20   -2.344293  3.143509    Sergio Busquets
# 21   -2.666436 -0.813176          E. Cavani
# 22   17.725204 -1.631702           M. Neuer
# 23   -2.787655 -4.365799          S. Agüero
# 24    1.611253  5.989787       G. Chiellini
# 25   -3.468857 -3.538644          K. Mbappé
# 26   -3.440163 -2.937032           M. Salah
# 27   -2.075401  3.996813           Casemiro
# 28   -3.278768 -2.325550       J. Rodríguez
# 29   -2.734207 -5.222954         L. Insigne
# ..         ...       ...                ...
# 80   -2.577085 -3.194739           N. Fekir
# 81   18.553414 -1.533574            Alisson
# 82   -3.326563  0.943231         J. Kimmich
# 83   -3.399290  1.457313               Saúl
# 84   -2.466320 -4.090393          R. Mahrez
# 85   -3.705954  1.173279           D. Alaba
# 86   -3.425760  0.118759               Koke
# 87   -2.344971 -2.681405       A. Lacazette
# 88    3.878313  6.294166         K. Manolas
# 89    0.738792  4.948831        N. Otamendi
# 90   -2.634342  0.643668             Parejo
# 91   -3.494608  2.002514           Paulinho
# 92   18.934337 -1.121357        W. Szczęsny
# 93   -2.897762 -2.321412         A. Sánchez
# 94   -2.166750 -3.753740         Y. Brahimi
# 95   -0.055251  4.774413         J. Boateng
# 96   -3.717104  2.486734           A. Vidal
# 97   -3.688095 -0.151011         I. Perišić
# 98   -0.516916 -0.358541           E. Džeko
# 99   -2.661584  3.123124         S. Khedira
# 100  -0.772719  0.144538        Diego Costa
# 101  -4.028397  1.824607      R. Nainggolan
# 102   0.081523  4.518121              Naldo
# 103  -2.920445  2.642677         B. Matuidi
# 104   0.882541  4.968159            Miranda
# 105  -1.458081 -2.661787         K. Benzema
# 106  -2.714554  2.392151        Filipe Luís
# 107   0.784593  4.941324         V. Kompany
# 108   1.749388  5.147898               Pepe
# 109  -1.101967 -1.384143     Z. Ibrahimović
#
# [110 rows x 3 columns]

# %%
# The explained variance tells us how much information (variance) can be attributed to each of the principal components
pca.explained_variance_ratio_
# Out:
# array([0.65597698, 0.14857827])

# %%
# Show the total explained variance ratio of model
sum(pca.explained_variance_ratio_) * 100
# Out:
# 80.45552504533683

# %% [markdown]
# ## PCA Visualization

# %%
# Create scatter plot with players label
fig, ax2 = plt.subplots(figsize = (16, 16))

# Create scatter plot
plot = sns.regplot(ax = ax2, data = pcaDF, x = "PC1", y = "PC2", fit_reg = False
                   , marker = "o", color = "#4682B4", scatter_kws = {"s": 100})
 
# Add annotations one by one with a loop
for line in range(0, pcaDF.shape[0]):
    plot.text(pcaDF.PC1[line] + 0.2, pcaDF.PC2[line], pcaDF.Name[line], horizontalalignment='left'
            , size='medium', color='black', weight='normal')

# Plot setup
ax1.set_xlabel("PC 1", fontsize = 12)
ax1.set_ylabel("PC 2", fontsize = 12)
ax1.set_title("Best Players FIFA 19", fontsize = 20)
ax1.legend(["Best Players (overall >= 85)"])
ax1.grid()

# %% [markdown]
# ----
# <a href="https://github.com/ansegura7/DataScience_FIFA19Data">&laquo; 0. GitHub Repository</a>
#
# <a href="https://ansegura7.github.io/DataScience_FIFA19Data/pages/QueryingData.html">&laquo; 2. Querying Data</a>
